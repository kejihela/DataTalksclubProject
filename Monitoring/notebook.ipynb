# %%
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_absolute_error
import pandas as pd
import pickle
from sklearn.feature_extraction import DictVectorizer

# %%
df = pd.read_csv("https://raw.githubusercontent.com/kejihela/DataTalksclubProject/master/dataset/flight_dataset.csv")
df
# Out:
#            Airline    Source Destination  Total_Stops  Price  Date  Month  \
# 0           IndiGo  Banglore   New Delhi            0   3897    24      3
# 1        Air India   Kolkata    Banglore            2   7662     1      5
# 2      Jet Airways     Delhi      Cochin            2  13882     9      6
# 3           IndiGo   Kolkata    Banglore            1   6218    12      5
# 4           IndiGo  Banglore   New Delhi            1  13302     1      3
# ...            ...       ...         ...          ...    ...   ...    ...
# 10678     Air Asia   Kolkata    Banglore            0   4107     9      4
# 10679    Air India   Kolkata    Banglore            0   4145    27      4
# 10680  Jet Airways  Banglore       Delhi            0   7229    27      4
# 10681      Vistara  Banglore   New Delhi            0  12648     1      3
# 10682    Air India     Delhi      Cochin            2  11753     9      5
#
#        Year  Dep_hours  Dep_min  Arrival_hours  Arrival_min  Duration_hours  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10683 entries, 0 to 10682
# Data columns (total 14 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Airline         10683 non-null  object
#  1   Source          10683 non-null  object
#  2   Destination     10683 non-null  object
#  3   Total_Stops     10683 non-null  int64
#  4   Price           10683 non-null  int64
#  5   Date            10683 non-null  int64
#  6   Month           10683 non-null  int64
#  7   Year            10683 non-null  int64
#  8   Dep_hours       10683 non-null  int64
#  9   Dep_min         10683 non-null  int64
#  10  Arrival_hours   10683 non-null  int64
#  11  Arrival_min     10683 non-null  int64
#  12  Duration_hours  10683 non-null  int64
#  13  Duration_min    10683 non-null  int64
# dtypes: int64(11), object(3)
# memory usage: 1.1+ MB

# %%
categorical = ["Airline", "Source", "Destination"]
numerical = ["Total_Stops","Duration_hours","Duration_min"]

# %%
df = df[categorical + numerical]
df
# Out:
#            Airline    Source Destination  Total_Stops  Duration_hours  \
# 0           IndiGo  Banglore   New Delhi            0               2
# 1        Air India   Kolkata    Banglore            2               7
# 2      Jet Airways     Delhi      Cochin            2              19
# 3           IndiGo   Kolkata    Banglore            1               5
# 4           IndiGo  Banglore   New Delhi            1               4
# ...            ...       ...         ...          ...             ...
# 10678     Air Asia   Kolkata    Banglore            0               2
# 10679    Air India   Kolkata    Banglore            0               2
# 10680  Jet Airways  Banglore       Delhi            0               3
# 10681      Vistara  Banglore   New Delhi            0               2
# 10682    Air India     Delhi      Cochin            2               8
#
#        Duration_min
# 0                50
# 1                25
# 2                 0
# 3                25
# ...

# %%
df.Duration_hours = df.Duration_hours *60
df
# Out:
# /tmp/ipykernel_4222/4098694595.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.Duration_hours = df.Duration_hours *60
#            Airline    Source Destination  Total_Stops  Duration_hours  \
# 0           IndiGo  Banglore   New Delhi            0             120
# 1        Air India   Kolkata    Banglore            2             420
# 2      Jet Airways     Delhi      Cochin            2            1140
# 3           IndiGo   Kolkata    Banglore            1             300
# 4           IndiGo  Banglore   New Delhi            1             240
# ...            ...       ...         ...          ...             ...
# 10678     Air Asia   Kolkata    Banglore            0             120
# ...

# %%
df["duration"] = df["Duration_hours"] + df["Duration_min"]
df
# Out:
# /tmp/ipykernel_4222/3890359722.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["duration"] = df["Duration_hours"] + df["Duration_min"]
#            Airline    Source Destination  Total_Stops  Duration_hours  \
# 0           IndiGo  Banglore   New Delhi            0             120
# 1        Air India   Kolkata    Banglore            2             420
# 2      Jet Airways     Delhi      Cochin            2            1140
# 3           IndiGo   Kolkata    Banglore            1             300
# 4           IndiGo  Banglore   New Delhi            1             240
# ...            ...       ...         ...          ...             ...
# 10678     Air Asia   Kolkata    Banglore            0             120
# ...

# %%
df = df.drop(["Duration_hours", "Duration_min", "duration"], axis = 1)
df

# %%
target = df["duration"].values

# %%
df = df.to_dict(orient = "records")

# %%
dv = DictVectorizer()
df = dv.fit_transform(df)

# %%
train_df = df[:8000]
test_df = df[8000:]
y_train =  target[:8000]
y_test = target[8000:]

# %%
model = LinearRegression()
model.fit(train_df, y_train)
# Out:
# LinearRegression()

# %%
train_pred = model.predict(train_df)

# %%
mean_absolute_error(train_pred, y_train)
# Out:
# np.float64(0.0005153618839878469)

# %%
val_df = pd.DataFrame()

# %%
val_pred = model.predict(test_df)
val_df["prediction"] = val_pred

# %%
mean_absolute_error(val_pred, y_test)
# Out:
# np.float64(0.0005155412528269134)

# %%
with open('models/linear_reg.bin','wb') as f_out:
    pickle.dump(model, f_out)

# %%
val_df.to_csv("data/reference.csv")
